# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def f(x):
    return (x**2 - 3 * x) + 10 * np.random.rand()


vf = np.vectorize(f)

# %%
def grad_f(x):
    return 2 * x - 3

# %%
x = np.arange(-20, 20, 0.1)

# %%
y = vf(x)

# %%
plt.plot(x, y)

# %%
n_iters = 100
x_vals = [x_init]
losses = [f(x_init)]
x_init = -10
learning_rate = 0.1
x_opt = x_init

for _ in range(n_iters):
    x_opt = x_opt - learning_rate * grad_f(x_opt)
    x_vals.append(x_opt)
    losses.append(f(x_opt))

# %%
plt.plot(x_vals)

# %%
plt.plot(losses)
